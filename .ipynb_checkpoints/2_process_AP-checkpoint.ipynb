# %%
import pandas as pd
import numpy as np
import re
from pathlib import Path

# %% [markdown]
# # Paths and constants

# %%
input_dir = Path(r"C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Raw")
output_dir = Path(r"C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed")
volfilt_file = Path(r"C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\ap_VolFilt.csv")

# Make sure output dir exists
output_dir.mkdir(parents=True, exist_ok=True)

# Read volume filtered data
volfilt_data = pd.read_csv(volfilt_file)

# Fixed parameters
filterarea  = np.pi * 1.05**2 * 1e-4  # cm^2 → m^2
zerowvlnmin = 780
zerowvlnmax = 800

# %% [markdown]
# # Collect raw files

# %%
all_raw_files = list(input_dir.rglob("*_RawData.txt"))
all_raw_names = [f.name for f in all_raw_files]

# Files referenced in CSV (for info only)
csv_files = pd.concat(
    [volfilt_data["p_filename"], volfilt_data["d_filename"]],
    ignore_index=True
)
csv_files = csv_files.dropna().unique().tolist()

# %%
# Track missing files (referenced in CSV but not found) and processed bottles
missing_files = []
processed_keys = set()   # (cruise, cast, niskin)

# %% [markdown]
# # Processing functions

# %%
def read_spectrum_file(fname):
    """
    Read a LabSolutions UV-Vis text file where the numeric table starts
    after a line like:

        Wavelength (nm),Absorbance

    Returns
    -------
    wvln : np.ndarray
        Wavelengths (nm)
    absorb : np.ndarray
        Absorbance (unitless)
    """
    fname = Path(fname)
    header_row = None

    with fname.open("r") as f:
        for i, line in enumerate(f):
            if line.strip().startswith("Wavelength"):
                header_row = i
                break

    if header_row is None:
        raise ValueError(f"Could not find 'Wavelength' header in {fname}")

    df = pd.read_csv(
        fname,
        skiprows=header_row + 1,
        header=None,
        names=["Wavelength", "Absorbance"]
    )

    if df.shape[1] < 2:
        raise ValueError(
            f"File {fname} has only {df.shape[1]} column(s) after header."
        )

    return df["Wavelength"].to_numpy(), df["Absorbance"].to_numpy()


def apspecproc(apfilename, adfilename, volfilt, filterarea,
               zerowvlnmin, zerowvlnmax):
    """
    Process raw absorbance data into absorption coefficients.
    Python version of apspecproc_Dec2012.
    """
    Mitcha = 0.392
    Mitchb = 0.655

    # ap
    wvln, abs_ap = read_spectrum_file(apfilename)

    zero_range = (wvln >= zerowvlnmin) & (wvln <= zerowvlnmax)
    if not np.any(zero_range):
        raise ValueError(
            f"No wavelengths in [{zerowvlnmin}, {zerowvlnmax}] in {apfilename}"
        )

    ap_zero = abs_ap[zero_range].mean()
    ap_corrected = abs_ap - ap_zero
    ap_od = Mitcha * ap_corrected + Mitchb * ap_corrected**2
    ap = 2.3 * ap_od / (volfilt / filterarea)

    # ad
    if adfilename is not None:
        _, abs_ad = read_spectrum_file(adfilename)
        ad_zero = abs_ad[zero_range].mean()
        ad_corrected = abs_ad - ad_zero
        ad_od = Mitcha * ad_corrected + Mitchb * ad_corrected**2
        ad = 2.3 * ad_od / (volfilt / filterarea)
    else:
        abs_ad = np.full_like(abs_ap, np.nan, dtype=float)
        ad = np.full_like(ap, -9999.0, dtype=float)

    aph = ap - ad

    return wvln, ap, aph, ad, abs_ap, abs_ad


def parse_key_from_filename(name):
    """
    Parse (cruise, cast, niskin) from a filename stem such as:
        EN715_C23N14da_RawData
    or with extension:
        EN715_C23N14da_RawData.txt
    Returns (cruise, cast, niskin) or None if pattern not found.
    """
    # Use only the stem part for safety
    stem = Path(name).stem              # EN715_C23N14da_RawData
    m = re.match(r"([A-Za-z0-9]+)_C(\d+)N(\d+)", stem)
    if not m:
        return None
    cruise = m.group(1).upper()
    cast = int(m.group(2))
    niskin = int(m.group(3))
    return (cruise, cast, niskin)

# %% [markdown]
# # Main loop over rows

# %%
for i, row in volfilt_data.iterrows():
    apfile = row.get("p_filename")
    adfile = row.get("d_filename")

    # Missing filenames in CSV
    if pd.isna(apfile) or pd.isna(adfile):
        print(f"Skipping pair: {apfile} / {adfile} (filename missing in CSV)")
        if isinstance(apfile, str):
            missing_files.append(apfile)
        if isinstance(adfile, str):
            missing_files.append(adfile)
        continue

    ap_path = input_dir / apfile
    ad_path = input_dir / adfile

    # Check existence
    if not ap_path.is_file() or not ad_path.is_file():
        print(f"Skipping pair: {apfile} / {adfile} (file not found)")
        if not ap_path.is_file():
            missing_files.append(apfile)
        if not ad_path.is_file():
            missing_files.append(adfile)
        continue

    # Volume in mL to m^3
    if "Ap_vol" in volfilt_data.columns:
        vol_mL = row["Ap_vol"]
    elif "volume_filtered" in volfilt_data.columns:
        vol_mL = row["volume_filtered"]
    else:
        raise ValueError(
            f"No Ap_vol or volume_filtered column found in {volfilt_file}"
        )

    if not np.isfinite(vol_mL):
        print(f"Skipping {apfile}: invalid volume {vol_mL}.")
        continue

    volfilt = vol_mL * 1e-6

    # Process spectra
    try:
        wvln, ap, aph, ad, abs_ap, abs_ad = apspecproc(
            ap_path, ad_path, volfilt, filterarea,
            zerowvlnmin, zerowvlnmax
        )
    except Exception as e:
        print(f"Error processing {apfile} / {adfile}: {e}")
        continue

    # Output name from ap filename
    base = Path(apfile).stem  # EN715_C23N14da_RawData
    base_clean = re.sub(r"(p[a-z]|d[a-z])_RawData$", "", base)
    processed_name = base_clean + "_Processed.csv"
    output_file = output_dir / processed_name

    output_table = pd.DataFrame({
        "Wavelength": wvln,
        "Particle_Absorption": ap,
        "Phytoplankton_Absorption": aph,
        "Detritus_Absorption": ad,
        "Raw_Absorbance_ap": abs_ap,
        "Raw_Absorbance_ad": abs_ad,
    })

    output_table.to_csv(output_file, index=False)

    # Mark this bottle as processed based on the ap file name
    key = parse_key_from_filename(apfile)
    if key is not None:
        processed_keys.add(key)
# Out:
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C01N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C01N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C01N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C01N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C01N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C01N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C04N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C05N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C05N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C05N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C05N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C05N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C05N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C10N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C10N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C10N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C10N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C10N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C10N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C10N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N21_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N21_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C11N21_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C12N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C12N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C12N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C12N24_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C12N24_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C12N24_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C15N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C15N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C15N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C15N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C15N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C15N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C16N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C16N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C16N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C16N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C16N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C16N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C16N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C17N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C18N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C19N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C19N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C19N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C19N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C20N01_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C20N01_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C20N01_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C20N03_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C20N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C20N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AE2426_C20N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C01N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C01N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C01N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C01N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C01N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C01N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C02N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C02N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C03N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C03N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C03N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C03N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C03N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C04N03_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C04N03_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C04N03_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C04N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C05N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C05N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C05N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C05N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C05N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C05N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C10N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C10N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C10N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C10N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C10N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C10N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C17N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C17N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C17N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C17N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C17N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C17N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C27N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C27N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C27N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C27N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C27N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C27N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C28N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C28N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C28N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C28N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C37N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C37N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C37N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C37N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C37N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR28B_C37N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C04N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C04N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C04N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C07N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C07N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C07N17_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C07N22_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C07N22_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C07N22_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C09N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C09N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C09N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C11N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C11N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C11N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C18N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C18N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C18N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C18N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C18N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C18N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C32N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C32N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\AR61B_C32N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C01N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C01N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C01N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C01N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C01N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C01N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C01N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C04N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C04N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C04N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C04N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C05N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C08N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C08N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C08N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C08N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C08N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C08N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C08N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C09N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C09N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C09N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C09N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C12N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C12N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C12N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C12N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C12N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C12N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C12N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C14N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C14N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C14N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C14N22_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C14N22_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C14N22_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C15N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C19N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C19N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C19N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C19N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C19N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C19N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C21N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C21N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C21N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C21N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C21N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C21N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C21N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C22N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C22N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C22N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C22N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C22N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C22N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C30N01_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C30N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C30N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C30N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN608_C30N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C01N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C01N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C01N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C01N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C01N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C01N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C01N12_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C02N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C02N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C02N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C02N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C02N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C02N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C02N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C05N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C05N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C05N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C05N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C05N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C05N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C08N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C08N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C08N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C08N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C08N16_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C09N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C09N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C09N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C09N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C09N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C09N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C12N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C12N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C12N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C12N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C12N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C13N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C13N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C13N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C13N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C13N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C13N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C14N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN617_C14N10_Processed.csv
# ...
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C02N13_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C03N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C06N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C07N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C07N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C07N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C07N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C07N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C07N15_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N06_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N21_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N21_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C08N21_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N14_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C11N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N05_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C14N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N11_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C15N18_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C16N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C16N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C16N08_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C16N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C16N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C16N19_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C19N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C19N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C19N10_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C19N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C19N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C19N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C20N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C20N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C20N09_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C20N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C20N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C20N20_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N02_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N04_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N07_Processed.csv
# Processed and saved: C:\Users\ocron\OneDrive - Massachusetts Institute of Technology\Documents\Research\Generals\Research_Report3\Data\AP\Processed\EN720_C24N07_Processed.csv

# %% [markdown]
# # Report unused and missing

# %%
unused_files = []

for f in all_raw_files:
    key = parse_key_from_filename(f.name)
    if key is None:
        continue
    # If this bottle key was never processed, then this file belongs
    # to a bottle that had no usable run
    if key not in processed_keys:
        unused_files.append(f.name)

unused_files = sorted(set(unused_files))

if unused_files:
    print("\nRaw files whose bottle (cruise, cast, niskin) was never processed:")
    for fname in unused_files:
        print("   ", fname)
else:
    print("\nAll bottles had at least one representative file processed.")
# Out:
# Raw files whose bottle (cruise, cast, niskin) was never processed:
#     EN608_C05N05da_RawData.txt
#     EN608_C05N05db_RawData.txt
#     EN608_C05N05pa_RawData.txt
#     EN706_C20N11pa_RawData.txt

# %%
if missing_files:
    print("\nFiles referenced in CSV but missing on disk:")
    for fname in sorted(set(missing_files)):
        print("   ", fname)

print("\nBatch processing completed.")
# Out:
# Batch processing completed.
